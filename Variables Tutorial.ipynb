# %% [markdown]
# # Variables in Python

# %%
x = 22

print(x)
# Out:
# 22

# %%
type(x)
# Out:
# int

# %%
y = 'Chocolate Bar'

print(y)
# Out:
# Chocolate Bar

# %%
type(y)
# Out:
# str

# %%
y = 'Chocolate'

Y = 'Chocolate Bar'
print(Y)
# Out:
# Chocolate Bar

# %%
x,y,z = 'Chocolate', 'Vanilla', 'Strawberry'

print(x)
print(y)
print(z)
# Out:
# Chocolate
# Vanilla
# Strawberry

# %%
x=y=z= 'Root Beer Float'

print(x)
print(y)
print(z)
# Out:
# Root Beer Float
# Root Beer Float
# Root Beer Float

# %%
Ice_Cream = ['Chocolate', 'Vanilla', 'Strawberry']

x,y,z = Ice_Cream

print(x)
print(y)
print(z)
# Out:
# Chocolate
# Vanilla
# Strawberry

# %%
# Camel Case

#Test variable Case

testVariableCase = 'Vanilla Swirl'

# %%
# Pascal Case

#Test variable Case

TestVariableCase = 'Vanilla Swirl'

# %%
# Snake Case

#Test variable Case

test_variable_case = 'Vanilla Swirl'

# %%
testvar = 'Vanilla Swirl'
test_var = 'Vanilla Swirl'
_test_var = 'Vanilla Swirl'
testVar = 'Vanilla Swirl'
TestVar = 'Vanilla Swirl'
testVar2 = 'Vanilla Swirl'

# %%
2testVar = 'Vanilla Swirl'
test-Var2 = 'Vanilla Swirl'
test Var2 = 'Vanilla Swirl'
test,Var2 = 'Vanilla Swirl'

# %%
x = 'Youghurt is my favourite' + '.'

print (x)
# Out:
# Youghurt is my favourite.

# %%
Y=3+2

print(Y)
# Out:
# 5

# %%
x='Youghurt'
y=' is'
z=' my favourite.'

print (x+y+z)
# Out:
# Youghurt is my favourite.

# %%
x=1
y=2
z=3

print (x+y+z)
# Out:
# 6

# %%
x=2
y='Icecream'

print (x,y)
# Out:
# 2 Icecream
